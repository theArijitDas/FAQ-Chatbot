# %%
import sys
sys.path.append("..")
from Utils.utils import convert_pdf_to_csv

# %%
convert_pdf_to_csv('../Resources/FAQs.pdf', verbose=True, save=False)
# Out:
# Q0: Can I change my branch?
# A0: Yes, you can change i t at the end of the first year ( refer to Chapter 2 of the  UG
#
# Q1: Can I take only one branch?
# A1: Yes, you can  have only one major branch , while you may opt for a minor branch
#
# Q2: Can Integrated M.  Tech students change their program  to B.  Tech?
# A2: Yes, you can change i t at the end of the first year ( refer to Chapter 2 of the  UG
#
# Q3: If I can't manage the load of an additional program, can I drop Minor/Double
# A3: Yes, it's possible to drop any additional programs after it's allocation. If you
#
# Q4: Can Int. M . Tech stud ent apply for Double Major and Dual Degree?
# A4: No. Only students under BTech program can apply for Double Major and Dual
#
# Q5: Can Int. M . Tech student take Minor programs?
# A5: Yes, they can do so. Yes, you can  have only one major branch , while you may
#
# Q6: Is the workload of double major manageable?
# A6: Yes, the students are successfully managing the course.
#
# ...
